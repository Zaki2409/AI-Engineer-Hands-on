# %%
import pandas as pd

# %%
data = pd.read_csv('datasets/swmh/train.csv')

# %%
data.head()
# Out:
#                                                 text              label
# 0  wanting to skip or postpone my exam my exam is...       self.Anxiety
# 1  Do other bipolar folks have problems with subs...       self.bipolar
# 2  Wanted to share some revelations I just had to...    self.depression
# 3  I feel deader than dead. I find that I don't h...  self.SuicideWatch
# 4  I'm pretty sure my friends suicidal what do I ...  self.SuicideWatch

# %%
data1 = pd.read_csv('datasets/swmh/test.csv')

# %%
data1.head()
# Out:
#                                                 text              label
# 0  Suicidal, but won't do it. Just need someone t...  self.SuicideWatch
# 1  A lie. A lie ruined my life A lie.\n\n\nA lie ...    self.offmychest
# 2  Suicidal Thoughts and Venting I would first li...  self.SuicideWatch
# 3  Guided Meditation Disclaimer:  I am in no way ...       self.bipolar
# 4  Effexor day 1 is going badly Good news! So the...       self.Anxiety

# %%
data2 = pd.read_csv('datasets/swmh/val.')

# %%
data2.head()
# Out:
#                                                 text              label
# 0  I can't make money I can't live in a world whe...       self.bipolar
# 1  "How are you?" "I'm fine," "How are you?" "I'm...    self.offmychest
# 2  I'm fed up I'm fed up with all this world, it'...  self.SuicideWatch
# 3  Can depression "evolve" to bipolar over time w...       self.bipolar
# 4  Any words of encouragement Hello I posted year...    self.depression

# %%
#concat
concat = pd.concat([data,data1,data2])

# %%
concat
# Out:
#                                                    text              label
# 0     wanting to skip or postpone my exam my exam is...       self.Anxiety
# 1     Do other bipolar folks have problems with subs...       self.bipolar
# 2     Wanted to share some revelations I just had to...    self.depression
# 3     I feel deader than dead. I find that I don't h...  self.SuicideWatch
# 4     I'm pretty sure my friends suicidal what do I ...  self.SuicideWatch
# ...                                                 ...                ...
# 8701  I stopped Lamictal after it screwed up my visi...       self.bipolar
# 8702  I'm afraid my ex committed suicide what do I d...  self.SuicideWatch
# 8703  Failed college 2 times it was +10 years ago. I...    self.depression
# 8704  Put on some music that you find beautiful and ...       self.Anxiety
# 8705  Discovered that my friend made a blog and toda...    self.depression
#
# [54412 rows x 2 columns]

# %%
concat1 = pd.concat([data,data1,data2], axis=0, ignore_index=True)

# %%
concat1.head(50)
# Out:
#                                                  text              label
# 0   wanting to skip or postpone my exam my exam is...       self.Anxiety
# 1   Do other bipolar folks have problems with subs...       self.bipolar
# 2   Wanted to share some revelations I just had to...    self.depression
# 3   I feel deader than dead. I find that I don't h...  self.SuicideWatch
# 4   I'm pretty sure my friends suicidal what do I ...  self.SuicideWatch
# 5   Self-harm urges are getting stronger Hey every...    self.depression
# 6   Anonymous Entry: plz be nice My brain boils no...    self.depression
# 7   I'm drowning. I don't remember ever really bei...    self.depression
# 8   ANYONE here ever tried r-TMS (repeated Transcr...       self.bipolar
# 9   Anyone else just afraid of life? First off, if...    self.depression
# 10  Serious Question about suicide Why do we have ...    self.depression
# 11  i dont know why it bothers me when my friend t...    self.depression
# ...

# %%
concat1.to_csv("swmh.csv")

# %%
concat1.to_csv("datasets/swmh/swmh.csv", index=False)

# %% [markdown]
# ## NOW WE CAN USE THE swmh DATASET
